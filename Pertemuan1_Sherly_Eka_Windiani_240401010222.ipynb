# %% [markdown]
# <a href="https://colab.research.google.com/github/sherlyekawindiani/data-science-2026/blob/master/Pertemuan1_Sherly_Eka_Windiani_240401010222.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PERTEMUAN 1: PENGENALAN DATA SCIENCE
# ### NAMA  : SHERLY EKA WINDIANI
# ### NIM   : 240401010222
# ### KELAS : IF403

# %%
# ================================================
# PERTEMUAN 1: Notebook Pertama Data Science
# ================================================

# SEL 1: Output sederhana
print("Hello, Data Science!")
print("Selamat datang di mata kuliah Pengantar Data Science!")
# Out:
# Hello, Data Science!
# Selamat datang di mata kuliah Pengantar Data Science!

# %%
# SEL 2: Variabel dan tipe data dasar
nama = "Mahasiswa Informatika" # String
angkatan = 2024 # Integer
ipk = 3.75 # Float
aktif = True # Boolean

print(f"Nama : {nama}")
print(f"Angkatan: {angkatan}")
print(f"IPK : {ipk}")
print(f"Aktif : {aktif}")
# Out:
# Nama : Mahasiswa Informatika
# Angkatan: 2024
# IPK : 3.75
# Aktif : True

# %%
# SEL 3: List dan perulangan
tools = ["Python", "Google Colab", "Jupyter Notebook", "GitHub"]
print("\nTools Data Science yang akan kita pelajari:")
for i, tool in enumerate(tools, 1):
  print(f" {i}. {tool}")
# Out:
# Tools Data Science yang akan kita pelajari:
#  1. Python
#  2. Google Colab
#  3. Jupyter Notebook
#  4. GitHub

# %%
# SEL 4: Fungsi sederhana
def perkenalan(nama, prodi, angkatan):
  """Fungsi untuk menampilkan perkenalan mahasiswa."""
  return f"Hai! Saya {nama} dari {prodi}, angkatan {angkatan}."

hasil = perkenalan("Sherly Eka Windiani", "Informatika", 2024)
print(hasil)
# Out:
# Hai! Saya Sherly Eka Windiani dari Informatika, angkatan 2024.

# %% [markdown]
# ## KESIMPULAN
# ### 1. Materi yang Dipelajari
# - Mengenal dasar-dasar Data Science dengan menggunakan **Google Colab** untuk menuliskan dan menjalankan kode Python.
# - Mempelajari sintaks dasar Python, seperti penggunaan fungsi `print`, pembuatan variabel dengan berbagai tipe data (string, integer, float, dan boolean), pengelolaan data menggunakan *list*, serta pembuatan *function* sederhana untuk membantu mengotomatisasi pekerjaan tertentu.
#
# ### 2. Hasil dan Temuan
# - Google Colab memudahkan proses penulisan dan eksekusi program karena dapat dijalankan langsung melalui browser tanpa perlu menginstal Python di perangkat.
# - Python memiliki sintaks yang cukup sederhana dan mudah dipahami oleh pemula. Salah satu fitur yang menarik adalah `f-string`, yang mempermudah penyisipan nilai variabel ke dalam teks sehingga output menjadi lebih rapi dan mudah dibaca.
#
# ### 3. Keterbatasan dan Pertanyaan yang Muncul
# * **Keterbatasan:** pembelajaran masih berfokus pada fitur-fitur dasar Python dan belum membahas penggunaan *library* yang umum digunakan dalam Data Science, seperti untuk pengolahan data maupun visualisasi data.
# * **Pertanyaan yang Muncul:** adalah bagaimana cara memanfaatkan *library* Data Science untuk mengolah data dalam jumlah besar dan menampilkan hasil analisis dalam bentuk visual yang lebih informatif.
